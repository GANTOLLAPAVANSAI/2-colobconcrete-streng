# %% [markdown]
# <a href="https://colab.research.google.com/github/GANTOLLAPAVANSAI/2-colobconcrete-streng/blob/main/concretestrength.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
concrete=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Concrete%20Compressive%20Strength.csv')
concrete
# Out:
#       Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# 0                            540.0                                       0.0
# 1                            540.0                                       0.0
# 2                            332.5                                     142.5
# 3                            332.5                                     142.5
# 4                            198.6                                     132.4
# ...                            ...                                       ...
# 1025                         276.4                                     116.0
# 1026                         322.2                                       0.0
# 1027                         148.5                                     139.4
# 1028                         159.1                                     186.7
# 1029                         260.9                                     100.5
#
# ...

# %%
concrete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Cement (kg in a m^3 mixture)                      1030 non-null   float64
#  1   Blast Furnace Slag (kg in a m^3 mixture)          1030 non-null   float64
#  2   Fly Ash (kg in a m^3 mixture)                     1030 non-null   float64
#  3   Water (kg in a m^3 mixture)                       1030 non-null   float64
#  4   Superplasticizer (kg in a m^3 mixture)            1030 non-null   float64
#  5   Coarse Aggregate (kg in a m^3 mixture)            1030 non-null   float64
#  6   Fine Aggregate (kg in a m^3 mixture)              1030 non-null   float64
#  7   Age (day)                                         1030 non-null   int64
#  8   Concrete Compressive Strength(MPa, megapascals)   1030 non-null   float64
# ...

# %%
concrete.head()
# Out:
#    Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# 0                         540.0                                       0.0
# 1                         540.0                                       0.0
# 2                         332.5                                     142.5
# 3                         332.5                                     142.5
# 4                         198.6                                     132.4
#
#    Fly Ash (kg in a m^3 mixture)  Water (kg in a m^3 mixture)  \
# 0                            0.0                        162.0
# 1                            0.0                        162.0
# 2                            0.0                        228.0
# 3                            0.0                        228.0
# 4                            0.0                        192.0
#
#    Superplasticizer (kg in a m^3 mixture)  \
# 0                                     2.5
# 1                                     2.5
# ...

# %%
concrete.describe()
# Out:
#        Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# count                   1030.000000                               1030.000000
# mean                     281.165631                                 73.895485
# std                      104.507142                                 86.279104
# min                      102.000000                                  0.000000
# 25%                      192.375000                                  0.000000
# 50%                      272.900000                                 22.000000
# 75%                      350.000000                                142.950000
# max                      540.000000                                359.400000
#
#        Fly Ash (kg in a m^3 mixture)  Water (kg in a m^3 mixture)  \
# count                    1030.000000                  1030.000000
# mean                       54.187136                   181.566359
# std                        63.996469                    21.355567
# ...

# %%
concrete.columns
# Out:
# Index(['Cement (kg in a m^3 mixture)',
#        'Blast Furnace Slag (kg in a m^3 mixture)',
#        'Fly Ash (kg in a m^3 mixture)', 'Water (kg in a m^3 mixture)',
#        'Superplasticizer (kg in a m^3 mixture)',
#        'Coarse Aggregate (kg in a m^3 mixture)',
#        'Fine Aggregate (kg in a m^3 mixture)', 'Age (day)',
#        'Concrete Compressive Strength(MPa, megapascals) '],
#       dtype='object')

# %%
y = concrete['Concrete Compressive Strength(MPa, megapascals) ']

# %%
X=concrete[['Cement (kg in a m^3 mixture)',
       'Blast Furnace Slag (kg in a m^3 mixture)',
       'Fly Ash (kg in a m^3 mixture)', 'Water (kg in a m^3 mixture)',
       'Superplasticizer (kg in a m^3 mixture)',
       'Coarse Aggregate (kg in a m^3 mixture)',
       'Fine Aggregate (kg in a m^3 mixture)', 'Age (day)']]

# %%
concrete.shape
# Out:
# (1030, 9)

# %%
y.shape
# Out:
# (1030,)

# %%
X.shape
# Out:
# (1030, 8)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
X_train
# Out:
#      Cement (kg in a m^3 mixture)  Blast Furnace Slag (kg in a m^3 mixture)  \
# 79                         531.30                                       0.0
# 193                        233.81                                       0.0
# 367                        214.90                                      53.8
# 181                        389.90                                     189.0
# 711                        305.30                                     203.5
# ..                            ...                                       ...
# 277                        251.37                                       0.0
# 763                        385.00                                       0.0
# 835                        144.00                                       0.0
# 559                        239.60                                     359.4
# 684                        192.00                                     288.0
#
# ...

# %%
#select the model 
from sklearn.linear_model import LinearRegression
model_L=LinearRegression()

# %%
model_L.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_L.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.32750521986239195

# %%
model_L.score(X_test,y_test)
# Out:
# 0.6234144623557857

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
# Out:
# 95.90413603833323
